# %%
from chaotic import *
# %matplotlib  inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Part 1

# %% [markdown]
# # part 1.1

# %%
plot_logistic_map(.5, .2)
# plot_logistic_map(.5, .6)
plot_logistic_map(1.5, .2)

# %%
plot_bifurcation(0, 2, .4)

# %% [markdown]
# # part 1.2

# %%
plot_logistic_map(2.5, .2)
plot_logistic_map(3.25, .2)
plot_logistic_map(3.75, .2)

# %%
plot_bifurcation(2, 4, .2)

# %% [markdown]
# # part 1.3

# %%
plot_bifurcation(0, 4, .2)

# %% [markdown]
# # Part 2

# %%
# %matplotlib Qt
difference([10, 10, 10], [10+1e-8, 10, 10], 10, 8/3, 28)
# Out:
# The difference between the points on the trajectory larger than 1 at 24.81s

# %%
difference([10, 10, 10], [10+1e-8, 10, 10], 10, 8/3, 0.5)
