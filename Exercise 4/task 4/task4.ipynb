# %%
import  numpy  as  np 
import  matplotlib.pyplot  as  plt
from chaotic import *
# %matplotlib  inline

# %% [markdown]
# ## Part 1

# %%
x = np.linspace(0, 1)
plt.figure(figsize=(5,5))
plt.plot(x, logistic(2, x), 'k')
plt.xlabel("x_n")
plt.ylabel("x_n+1")
plt.title("$r=2.0, x_0=0$")
# Out:
# Text(0.5, 1.0, '$r=2.0, x_0=0$')

# %% [markdown]
# # part 1.1

# %%
plot_logistic_map(.5, .1)
# plot_logistic_map(.5, .6)
plot_logistic_map(1.5, .1)

# %%
plot_bifurcation(0, 2, .1)

# %% [markdown]
# # part 1.2

# %%
plot_logistic_map(3.25, .1)
plot_logistic_map(3.75, .1)

# %%
plot_bifurcation(2, 4, .1)

# %% [markdown]
# # part 1.3

# %%
plot_bifurcation(0, 4, .1)

# %% [markdown]
# # Part 2

# %%
difference([10, 10, 10], [10+1e-8, 10, 10], 10, 8/3, 28)
# Out:
# The difference between the points on the trajectory larger than 1 at t = 22.55

# %%
difference([10, 10, 10], [10+1e-8, 10, 10], 10, 8/3, 0.5)
